# %%
import sys
import os
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), "../src"))
# Add it to sys.path
sys.path.append(project_root)

# %%
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from mpcc_models import TVDenoising
from dataset import get_dataset
from utils import plot_images_row

# %%
sz = 6
dataset = get_dataset("cameraman", scale=sz, random_state=100)
true, noisy = dataset.get_training_data()

# %%
den = TVDenoising(true,noisy)
res = den.solve(verbose=True, print_level=0, max_iter=50)
# Out:
# /Users/davidvillacis/workspace/bimpcc/src/nlp.py:96: OptimizeWarning: Unknown solver options: print_level, tol, max_iter, mu_strategy
#   result = minimize(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 den = TVDenoising(true,noisy)
# ----> 2 res = den.solve(verbose=True, print_level=0, max_iter=50)
#
# File ~/workspace/bimpcc/src/mpcc_models/reconstruction_tv.py:388, in TVRec.solve(self, max_iter, tol, nlp_tol, nlp_max_iter, verbose, print_level, x0, *args, **kwargs)
#     377 if x0 is None:
#     378     x0 = np.concatenate(
#     379         (
#     380             self.dmg_img.flatten(),
#    (...)
#     386         )
#     387     )
# --> 388 res, x, fn = super().solve(
#     389     x0,
#     390     max_iter,
#     391     tol,
#     392     nlp_tol,
#     393     nlp_max_iter,
#     394     verbose,
#     395     print_level,
# ...

# %%
plot_images_row([true, noisy, res["u"]], titles=["True Image", "Noisy Image",f"Denoised Image (Scholtes) [{res['alpha'][0]:.4f}]"])
